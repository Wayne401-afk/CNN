# %% [markdown]
# <a href="https://colab.research.google.com/github/Wayne401-afk/ECG-CNN/blob/main/CNN_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report
import seaborn as sns
from sklearn.utils import class_weight

# Verificar e instalar TensorFlow si no está instalado
try:
    import tensorflow as tf
except ModuleNotFoundError:
    import sys
    # !{sys.executable} -m pip install tensorflow
    import tensorflow as tf

# ----- Sistema dinámico -----
Gamma = 5
H = 3
t_span = (0, 11)  # Intervalo de tiempo
t_eval = np.linspace(*t_span, 1000)  # Puntos de evaluación

# Sistema de ecuaciones diferenciales
def sistema_ecuaciones(t, vars, Gamma, H):
    x, y, z, w = vars
    dxdt = Gamma * (x - y - 1.35 * x * y - x * y**2)
    dydt = Gamma * (H * x - 3 * y + 1.35 * x * y + x * y**2 + 4 * (w - y))
    dzdt = Gamma * (z - w - 1.35 * z * w - z * w**2)
    dwdt = Gamma * (H * z - 3 * w + 1.35 * z * w + z * w**2 + 2 * 4 * (y - w))
    return [dxdt, dydt, dzdt, dwdt]

# Generar soluciones para entrenamiento
num_samples = 500
alphas_train = np.random.rand(num_samples, 4)
signals_train = []

for alpha in alphas_train:
    sol = solve_ivp(sistema_ecuaciones, t_span, [0, 0, 0.1, 0], args=(Gamma, H), t_eval=t_eval)
    x, y, z, w = sol.y
    ecg_signal = alpha[0] * x + alpha[1] * y + alpha[2] * z + alpha[3] * w
    signals_train.append(ecg_signal)

signals_train = np.array(signals_train)

# ----- Autoencoder -----
input_dim = signals_train.shape[1]  # Número de puntos en la señal
encoding_dim = 16  # Dimensión comprimida

# Capa de entrada
input_signal = tf.keras.Input(shape=(input_dim,))

# Codificador
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_signal)

# Decodificador
decoded = tf.keras.layers.Dense(4, activation='linear')(encoded)

# Modelo autoencoder
autoencoder = tf.keras.Model(input_signal, decoded)

# Calcular pesos de clase (si las clases están desbalanceadas)
real_classes = np.round(alphas_train.sum(axis=1))
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(real_classes), y=real_classes)
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}

# Compilar el modelo
autoencoder.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
history = autoencoder.fit(signals_train, alphas_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1, class_weight=class_weights_dict)

# Graficar la pérdida y precisión durante el entrenamiento
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Curva de Pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida MSE')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# ----- Probar con una nueva señal -----
alpha_test = [0.1, 0.2, 0.3, 0.4]
sol = solve_ivp(sistema_ecuaciones, t_span, [0, 0, 0.1, 0], args=(Gamma, H), t_eval=t_eval)
x, y, z, w = sol.y
ecg_test = alpha_test[0] * x + alpha_test[1] * y + alpha_test[2] * z + alpha_test[3] * w

# Predecir alphas usando el autoencoder
predicted_alpha = autoencoder.predict(ecg_test.reshape(1, -1))[0]

print("Alpha real:", alpha_test)
print("Alpha predicho:", predicted_alpha)

# ----- Matriz de Confusión (Usando clases simuladas para demostración) -----
predicted_classes = np.round(autoencoder.predict(signals_train).sum(axis=1))
cm = confusion_matrix(real_classes, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusión')
plt.xlabel('Clases Predichas')
plt.ylabel('Clases Reales')
plt.show()

# Imprimir métricas detalladas
print("\nReporte de Clasificación:\n")
print(classification_report(real_classes, predicted_classes))

# ----- Curvas ROC y AUC (Para una clase simulada) -----
binary_true = (real_classes > 2).astype(int)
binary_pred_prob = autoencoder.predict(signals_train).sum(axis=1) / 4
fpr, tpr, _ = roc_curve(binary_true, binary_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Azar')
plt.title('Curva ROC')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.legend()
plt.grid()
plt.show()

# Graficar ejemplos de señales reconstruidas vs reales
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report
import seaborn as sns
from sklearn.utils import class_weight

# Verificar e instalar TensorFlow si no está instalado
try:
    import tensorflow as tf
except ModuleNotFoundError:
    import sys
    # !{sys.executable} -m pip install tensorflow
    import tensorflow as tf

# ----- Sistema dinámico -----
Gamma = 5
H = 3
t_span = (0, 11)  # Intervalo de tiempo
t_eval = np.linspace(*t_span, 1000)  # Puntos de evaluación

# Sistema de ecuaciones diferenciales
def sistema_ecuaciones(t, vars, Gamma, H):
    x, y, z, w = vars
    dxdt = Gamma * (x - y - 1.35 * x * y - x * y**2)
    dydt = Gamma * (H * x - 3 * y + 1.35 * x * y + x * y**2 + 4 * (w - y))
    dzdt = Gamma * (z - w - 1.35 * z * w - z * w**2)
    dwdt = Gamma * (H * z - 3 * w + 1.35 * z * w + z * w**2 + 2 * 4 * (y - w))
    return [dxdt, dydt, dzdt, dwdt]

# Generar soluciones para entrenamiento
num_samples = 500
alphas_train = np.random.rand(num_samples, 4)
signals_train = []

for alpha in alphas_train:
    sol = solve_ivp(sistema_ecuaciones, t_span, [0, 0, 0.1, 0], args=(Gamma, H), t_eval=t_eval)
    x, y, z, w = sol.y
    ecg_signal = alpha[0] * x + alpha[1] * y + alpha[2] * z + alpha[3] * w
    signals_train.append(ecg_signal)

signals_train = np.array(signals_train)

# ----- Autoencoder -----
input_dim = signals_train.shape[1]  # Número de puntos en la señal
encoding_dim = 16  # Dimensión comprimida

# Capa de entrada
input_signal = tf.keras.Input(shape=(input_dim,))

# Codificador
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_signal)

# Decodificador
decoded = tf.keras.layers.Dense(4, activation='linear')(encoded)

# Modelo autoencoder
autoencoder = tf.keras.Model(input_signal, decoded)

# Calcular pesos de clase (si las clases están desbalanceadas)
real_classes = np.round(alphas_train.sum(axis=1))
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(real_classes), y=real_classes)
class_weights_dict = {i: class_weights[i] for i in range(len(class_weights))}

# Compilar el modelo
autoencoder.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
history = autoencoder.fit(signals_train, alphas_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1, class_weight=class_weights_dict)

# Graficar la pérdida y precisión durante el entrenamiento
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Curva de Pérdida')
plt.xlabel('Épocas')
plt.ylabel('Pérdida MSE')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# ----- Probar con una nueva señal -----
alpha_test = [0.1, 0.2, 0.3, 0.4]
sol = solve_ivp(sistema_ecuaciones, t_span, [0, 0, 0.1, 0], args=(Gamma, H), t_eval=t_eval)
x, y, z, w = sol.y
ecg_test = alpha_test[0] * x + alpha_test[1] * y + alpha_test[2] * z + alpha_test[3] * w

# Predecir alphas usando el autoencoder
predicted_alpha = autoencoder.predict(ecg_test.reshape(1, -1))[0]

print("Alpha real:", alpha_test)
print("Alpha predicho:", predicted_alpha)

# ----- Matriz de Confusión (Usando clases simuladas para demostración) -----
predicted_classes = np.round(autoencoder.predict(signals_train).sum(axis=1))
cm = confusion_matrix(real_classes, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusión')
plt.xlabel('Clases Predichas')
plt.ylabel('Clases Reales')
plt.show()

# Imprimir métricas detalladas
print("\nReporte de Clasificación:\n")
print(classification_report(real_classes, predicted_classes))

# ----- Curvas ROC y AUC (Para una clase simulada) -----
binary_true = (real_classes > 2).astype(int)
binary_pred_prob = autoencoder.predict(signals_train).sum(axis=1) / 4
fpr, tpr, _ = roc_curve(binary_true, binary_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Azar')
plt.title('Curva ROC')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.legend()
plt.grid()
plt.show()

# Graficar ejemplos de señales reconstruidas vs reales
plt.figure(figsize=(12, 8))
for i in range(5):
    plt.plot(t_eval, signals_train[i], label=f'Real ECG {i+1}', linestyle='--')
    # Predict the alpha values for the current signal
    predicted_alpha = autoencoder.predict(signals_train[i].reshape(1, -1))[0]
    # Reconstruct the signal using the predicted alpha values
    sol = solve_ivp(sistema_ecuaciones, t_span, [0, 0, 0.1, 0], args=(Gamma, H), t_eval=t_eval)
    x, y, z, w = sol.y
    reconstructed_signal = predicted_alpha[0] * x + predicted_alpha[1] * y + predicted_alpha[2] * z + predicted_alpha[3] * w
    plt.plot(t_eval, reconstructed_signal, label=f'Reconstructed ECG {i+1}')
    plt.legend()
plt.title('Señales de ECG: Originales vs Reconstruidas')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid()
plt.show()
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 23.2566 - val_loss: 0.1721
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2587 - val_loss: 0.1401
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4987 - val_loss: 0.0558
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5999 - val_loss: 0.0516
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8280 - val_loss: 0.0604
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6857 - val_loss: 0.0437
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4554 - val_loss: 0.0289
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3155 - val_loss: 0.0316
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2143 - val_loss: 0.0231
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2094 - val_loss: 0.0292
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2660 - val_loss: 0.0207
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2050 - val_loss: 0.0247
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1824 - val_loss: 0.0193
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1732 - val_loss: 0.0209
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1639 - val_loss: 0.0166
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1470 - val_loss: 0.0218
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1325 - val_loss: 0.0151
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1347 - val_loss: 0.0171
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1035 - val_loss: 0.0160
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0965 - val_loss: 0.0150
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0890 - val_loss: 0.0114
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0984 - val_loss: 0.0124
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0902 - val_loss: 0.0132
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1129 - val_loss: 0.0121
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0787 - val_loss: 0.0121
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0864 - val_loss: 0.0109
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1868 - val_loss: 0.0185
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0792 - val_loss: 0.1456
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9710 - val_loss: 0.1229
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6491 - val_loss: 0.0577
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9879 - val_loss: 0.1049
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1129 - val_loss: 0.1644
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3585 - val_loss: 0.0877
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1850 - val_loss: 0.1307
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6019 - val_loss: 0.1023
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6750 - val_loss: 0.3427
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2458 - val_loss: 0.1066
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8093 - val_loss: 0.0192
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5993 - val_loss: 0.0140
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2619 - val_loss: 0.0096
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0839 - val_loss: 0.0082
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0680 - val_loss: 0.0070
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0426 - val_loss: 0.0071
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0410 - val_loss: 0.0059
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0322 - val_loss: 0.0065
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0390 - val_loss: 0.0055
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0272 - val_loss: 0.0051
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0304 - val_loss: 0.0054
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0312 - val_loss: 0.0043
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0287 - val_loss: 0.0046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Alpha real: [0.1, 0.2, 0.3, 0.4]
# Alpha predicho: [0.11290831 0.18803623 0.27908075 0.41149357]
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Reporte de Clasificación:
#
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.98      0.93       100
#          2.0       0.91      0.95      0.93       300
#          3.0       0.99      0.75      0.85        99
#          4.0       1.00      1.00      1.00         1
#
#     accuracy                           0.92       500
#    macro avg       0.95      0.92      0.93       500
# weighted avg       0.92      0.92      0.92       500
#
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 16.3504 - val_loss: 0.2335
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2596 - val_loss: 0.3390
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4889 - val_loss: 0.1734
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8597 - val_loss: 0.2005
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6173 - val_loss: 0.0849
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7756 - val_loss: 0.0766
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5936 - val_loss: 0.0555
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3921 - val_loss: 0.0516
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3928 - val_loss: 0.0525
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3281 - val_loss: 0.0549
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3630 - val_loss: 0.0520
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3175 - val_loss: 0.0496
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3181 - val_loss: 0.0456
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2672 - val_loss: 0.0476
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3222 - val_loss: 0.0452
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3164 - val_loss: 0.0444
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3248 - val_loss: 0.0449
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2525 - val_loss: 0.0435
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2517 - val_loss: 0.0426
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2935 - val_loss: 0.0427
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2598 - val_loss: 0.0414
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2381 - val_loss: 0.0394
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2870 - val_loss: 0.0405
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2487 - val_loss: 0.0409
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2593 - val_loss: 0.0414
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2868 - val_loss: 0.0420
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2695 - val_loss: 0.0414
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2651 - val_loss: 0.0468
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3424 - val_loss: 0.0400
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2656 - val_loss: 0.0440
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2657 - val_loss: 0.0419
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2950 - val_loss: 0.0410
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2491 - val_loss: 0.0394
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2744 - val_loss: 0.0420
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2565 - val_loss: 0.0518
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4335 - val_loss: 0.0480
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2782 - val_loss: 0.0392
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2844 - val_loss: 0.0411
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3386 - val_loss: 0.0650
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7134 - val_loss: 0.0531
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3076 - val_loss: 0.0414
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2470 - val_loss: 0.0404
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2785 - val_loss: 0.0410
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2585 - val_loss: 0.0396
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2352 - val_loss: 0.0395
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2404 - val_loss: 0.0397
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2062 - val_loss: 0.0390
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2045 - val_loss: 0.0386
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2277 - val_loss: 0.0393
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2294 - val_loss: 0.0391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Alpha real: [0.1, 0.2, 0.3, 0.4]
# Alpha predicho: [0.24273166 0.00929046 0.38953158 0.35415137]
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Reporte de Clasificación:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         2
#          1.0       0.96      0.96      0.96       111
#          2.0       0.95      0.99      0.97       293
#          3.0       1.00      0.89      0.94        94
#
#     accuracy                           0.96       500
#    macro avg       0.98      0.96      0.97       500
# weighted avg       0.96      0.96      0.96       500
#
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
plt.figure(figsize=(12, 8))
for i in range(5):
    plt.plot(t_eval, signals_train[i], label=f'Real ECG {i+1}', linestyle='--')
    # The output of the autoencoder has shape (4,) but we need a signal with 1000 points
    # We should use the decoder part of the autoencoder instead
    # First, obtain the encoded representation of the signal
    encoded_signal = autoencoder.layers[1](signals_train[i].reshape(1, -1)).numpy()
    # Then, use the decoder to reconstruct the signal
    reconstructed_signal = autoencoder.layers[2](encoded_signal).numpy()[0]
    plt.plot(t_eval, reconstructed_signal, label=f'Reconstructed ECG {i+1}')
